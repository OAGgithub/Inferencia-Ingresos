# %%
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import re

# %%
df = pd.read_excel('/content/sample_data/NÓMINA FIJA PARA TRANSPARENCIA ENERO 2023 (3).xlsx')
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-717ca965b995> in <cell line: 1>()
# ----> 1 df = pd.read_excel('/content/sample_data/NÓMINA FIJA PARA TRANSPARENCIA ENERO 2023 (3).xlsx')
#       2 df.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
df.drop(['No.','ESTATUS','FECHA DE ENTRADA','ISR','OTROS DESCUENTOS','TOTAL DESCUENTOS'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NOMBRE        290 non-null    object
#  1   CARGO         290 non-null    object
#  2   ÁREA          290 non-null    object
#  3   SEXO          290 non-null    object
#  4   SUELDO BRUTO  290 non-null    float64
#  5   AFP           290 non-null    float64
#  6   SFS           290 non-null    float64
#  7   NETO          290 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 18.2+ KB

# %%
df.rename (columns= {"ÁREA" : "DEPARTAMENTO","NETO":"SUELDO NETO","NOMBRE":"Nombre","CARGO":"Cargo","DEPARTAMENTO":"Departamento","SEXO":"Sexo","SUELDO BRUTO":"Sueldo Bruto","AFP":"AFP","SFS":"SFS"}, inplace=True)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Nombre        290 non-null    object
#  1   Cargo         290 non-null    object
#  2   Departamento  290 non-null    object
#  3   Sexo          290 non-null    object
#  4   Sueldo Bruto  290 non-null    float64
#  5   AFP           290 non-null    float64
#  6   SFS           290 non-null    float64
#  7   SUELDO NETO   290 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 18.2+ KB
#                                Nombre                      Cargo  \
# 0           RAFAEL JESUS FELIZ GARCIA                   MINISTRO
# 1          ANA ELIZABETH DIAZ RAMIREZ       SECRETARIA EJECUTIVA
# 2                CAMILO CAMILO PUJOLS     ASISTENTE DEL DESPACHO
# 3          CRISTY MACOLLE ORTIZ ARIAS       SECRETARIA EJECUTIVA
# ...

# %%
file_name = 'ministeriojnomina.csv'
df.to_csv(file_name, index=False)
print(f'DataFrame guardado en {file_name}')
# Out:
# DataFrame guardado en ministeriojnomina.csv
